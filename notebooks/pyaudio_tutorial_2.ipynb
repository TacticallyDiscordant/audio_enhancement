# %% [markdown]
# from [this video](https://www.youtube.com/watch?v=aQKX3mrDFoY)

# %%
import pyaudio as pya
import struct
import time
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft
from tkinter import TclError

# %matplotlib tk

# %%
CHUNK = 512  # amount of data processed at once
FORMAT = pya.paInt16
CHANNELS = 1  # mono
RATE = 48000

# %%
fig, (ax, ax2 )= plt.subplots(2, figsize=(15, 8))

# pyaudio class instance
p = pya.PyAudio()

# stream object
stream = p.open(
    format=FORMAT,
    channels=CHANNELS,
    rate=RATE,
    input=True,
    output=True,
    frames_per_buffer=CHUNK
)

# variable for plotting
x = np.arange(0, 2 * CHUNK, 2)
x_fft = np.linspace(0, RATE, CHUNK)

# create a Line object with random data
line, = ax.plot(x, np.random.rand(CHUNK), '-', lw=2)
line_fft, = ax2.semilogx(x_fft, np.random.rand(CHUNK), '-', lw=2)
# axes formatting
ax.set_title('AUDIO WAVEFORM')
ax.set_xlabel('samples')
ax.set_ylabel('volume')
ax.set_ylim(-2048*30, 2048*30)
ax.set_xlim(0, 2 * CHUNK)


ax2.set_xlim(20, RATE / 2)
ax2.set_ylim(0, 100)

plt.show(block=False)

frame_count = 0
start_time = time.time()

while True:
    data = stream.read(CHUNK)
    data_int = struct.unpack(str(CHUNK) + 'h', data)
    line.set_ydata(data_int)
    
    y_fft = fft(data_int)
    line_fft.set_ydata(np.abs(y_fft[0:CHUNK]) * 2 / (256 * CHUNK))

    
    fig.canvas.draw()
    fig.canvas.flush_events()
    frame_count += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 48
#      44 y_fft = fft(data_int)
#      45 line_fft.set_ydata(np.abs(y_fft[0:CHUNK]) * 2 / (256 * CHUNK))
# ---> 48 fig.canvas.draw()
#      49 fig.canvas.flush_events()
#      50 frame_count += 1
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/matplotlib/backends/backend_tkagg.py:10, in FigureCanvasTkAgg.draw(self)
#       9 def draw(self):
# ---> 10     super().draw()
#      11     self.blit()
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/matplotlib/backends/backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/matplotlib/axes/_base.py:3190, in _AxesBase.draw(self, renderer)
#    3187     for spine in self.spines.values():
#    3188         artists.remove(spine)
# -> 3190 self._update_title_position(renderer)
#    3192 if not self.axison:
#    3193     for _axis in self._axis_map.values():
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/matplotlib/axes/_base.py:3144, in _AxesBase._update_title_position(self, renderer)
#    3142     _log.debug('top of Axes not in the figure, so title not moved')
#    3143     return
# -> 3144 if title.get_window_extent(renderer).ymin < top:
#    3145     _, y = self.transAxes.inverted().transform((0, top))
#    3146     title.set_position((x, y))
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/matplotlib/transforms.py:308, in BboxBase.ymin(self)
#     305 @property
#     306 def ymin(self):
#     307     """The bottom edge of the bounding box."""
# --> 308     return np.min(self.get_points()[:, 1])
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3302, in min(a, axis, out, keepdims, initial, where)
#    3190 @array_function_dispatch(_min_dispatcher)
#    3191 def min(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    3192         where=np._NoValue):
#    3193     """
#    3194     Return the minimum of an array or minimum along an axis.
#    3195
#    (...)   3300     6
#    3301     """
# -> 3302     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    3303                           keepdims=keepdims, initial=initial, where=where)
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:70, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      69 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 70     passkwargs = {k: v for k, v in kwargs.items()
#      71                   if v is not np._NoValue}
#      73     if type(obj) is not mu.ndarray:
#      74         try:
#
# KeyboardInterrupt:
