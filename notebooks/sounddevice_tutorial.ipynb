# %% [markdown]
# supposedly uses non-blocking stream to pass audio from input to output device
# [Documentation](https://python-sounddevice.readthedocs.io/en/0.5.3/usage.html)

# %%
import sounddevice as sd

# %%
duration = 5.5  # seconds

def callback(indata, outdata, frames, time, status):
    if status:
        print(status)
    outdata[:] = indata

with sd.Stream(channels=2, callback=callback):
    sd.sleep(int(duration * 1000))
# Out:
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       6     outdata[:] = indata
#       8 with sd.Stream(channels=2, callback=callback):
# ----> 9     sd.sleep(int(duration * 1000))
#
# File /mnt/Storages/Universe/Workspace/data_science_retreat/PortfolioProject/audio_enhancement/.venv/lib/python3.13/site-packages/sounddevice.py:712, in sleep(msec)
#     705 def sleep(msec):
#     706     """Put the caller to sleep for at least *msec* milliseconds.
#     707
#     708     The function may sleep longer than requested so don't rely on this
#     709     for accurate musical timing.
#     710
#     711     """
# --> 712     _lib.Pa_Sleep(msec)
#
# KeyboardInterrupt:

# %%
import sounddevice as sd
duration = 5.5  # seconds

def callback(indata, outdata, frames, time, status):
    if status:
        print(status)
    outdata[:] = indata

with sd.RawStream(channels=2, dtype='int24', callback=callback):
    sd.sleep(int(duration * 1000))
# Out:
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
# output underflow
